# %% [markdown]
# # Exploratory Data Analysis
#
# In this notebook, I will be analyzing, visually and statistically, the different features in the Heart Failure dataset
# from Kaggle. I want to see how each feature impacts the likelihood of Heart Failure and uncover hidden patterns within
# the data.

# %%
# Importing all the relevant libraries for Exploratory Data Analysis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

df = pd.read_csv('Data/heart.csv',index_col=0)
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  917.000000  917.000000   917.000000  917.000000  917.000000
# mean    53.509269  132.540894   243.211559    0.233370  136.789531
# std      9.437636   17.999749    53.430044    0.423206   25.467129
# min     28.000000   80.000000    85.000000    0.000000   60.000000
# 25%     47.000000  120.000000   214.000000    0.000000  120.000000
# 50%     54.000000  130.000000   237.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  917.000000    917.000000
# mean     0.886696      0.552890
# std      1.066960      0.497466
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
# I want to see how values for each feature are spread for having heart disease and not having heart disease

sns.catplot(x='ExerciseAngina',data=df, kind='count', hue='HeartDisease', height=5, aspect=2)
plt.title('Count of participants with and without Exercise Angina')
# Out:
# Text(0.5, 1.0, 'Count of participants with and without Exercise Angina')

# %%
# The chart to the left shows that people that expeirence ExerciseAngina have a higher likelihood of having
# heart disease
# let's take a look at how the other features compare between the Sexes
sns.catplot(x='ChestPainType',data=df, kind='count', hue='HeartDisease', height=5, aspect=2)
plt.title('Type of Chest Pain relating to Heart Disease')
# Out:
# Text(0.5, 1.0, 'Type of Chest Pain relating to Heart Disease')

# %%
# We can see above that Men/Women that experience Asymptomatic Chest pain have a higher likelihood of having disease

sns.catplot(x='Age',data=df, kind='count', hue='HeartDisease',col='Sex', height=5, aspect=2)

# %%
The data above is not normally distributed, the likelihood of NOT having heart disease is skewed towards the left tail
Middle aged people are more likely to have heart disease than younger or older men

# %%
sns.catplot(x='FastingBS',data=df, kind='count', hue='HeartDisease')
plt.title('Fasting Blood Sugar level relating to Heart Disease')
# Out:
# Text(0.5, 1.0, 'Fasting Blood Sugar level relating to Heart Disease')

# %%
Fasting blood sugar level above 120 mg/dl (characterized as 1 on the x-axis) has a high correlation with having HD

# %%
sns.catplot(x='RestingECG',data=df, kind='count', hue='HeartDisease')
plt.title('Participants RestingECG vs Heart Disease')
# Out:
# Text(0.5, 1.0, 'Participants RestingECG vs Heart Disease')

# %%
Proportinally, Resting ECG doesn't seem to be a tell on whether Men or Women have Heart Disease

# %%
sns.catplot(x='ST_Slope',data=df, kind='count', hue='HeartDisease')
plt.title('ST_Slope vs Heart Disease')
# Out:
# Text(0.5, 1.0, 'ST_Slope vs Heart Disease')

# %%
This is the most telling chart so far, people with a Flat or Downward ST Slope are more likely to have Heart Disease vs
people with an upward ST Slope
This is something to keep an eye on going forward

# %%
sex_HD_mean = df.groupby('Sex')['HeartDisease'].mean()
sex_HD_mean
# Out:
# Sex
# F    0.259067
# M    0.631215
# Name: HeartDisease, dtype: float64

# %%
Simply based on the averages (before further analysis), it looks like men have 60% more chance of having heart 
disease vs Women

# %%
sns.catplot(x='HeartDisease',y='RestingBP',data=df, kind='box')

# %%
The Median for RestingBP is about the same for groups with and without Heart Disease but the IQR range is larger
for people with Heart Disease. The minimum floor is lower and maximum floor is higher for people w HD as well.

# %%
sns.catplot(x='HeartDisease',y='Cholesterol',data=df, kind='box')

# %%
The 'Cholesterol' IQR range is much smaller for people with HD vs people without HD.
But, there are significantly more outliers in 'Cholesterol' for people with HD

# %%
sns.catplot(x='HeartDisease',y='Oldpeak',data=df, kind='box')

# %%
Regarding the ST depression, the IQR, minimum, and maximum for the people with heart disease is a much higher range
vs without people without heart disease. The median calculate ST Depression is higher than for people with heart
disease vs people without. 

ST depression value less than 0.5 is considered normal, which explains why the IQR for no HD is so close to 0.

# %%
sns.catplot(x='HeartDisease',y='MaxHR',data=df, kind='box')

# %%
Regarding the maximum HR, the IQR, minimum, and maximum for the people with heart disease is a much lower range
vs without people without heart disease. This could be explained by the fact that the heart of people without heart
disease functions better than the people without, on average.

# %%
sns.catplot(x='HeartDisease', y='RestingBP', data=df, kind='point', col='ST_Slope')

# %%
The chart in the middle shows a significant data point, people with a higher resting blood pressure and Flat ST slope 
tend to have heart disease. The bottom of the 95% confidence interval for Flat ST_slope for people with a heart disease
is higher than the top the of 95% confidence interval for people with a Flat st_slope.

# %% [markdown]
# # ECDF Analysis on 2 of the Categorical Variables

# %%
I am going to calculate the ECDF for each of the 3 ST_slope variables to see how many people on average, out of 100,
will have heart disease based on their ST Slope.

# %%
count_st = df['ST_Slope'].value_counts()
print(count_st)
count_flat_HR = df[(df['ST_Slope'] == 'Flat') & (df['HeartDisease'] == 1)].count()
count_up_HR = df[(df['ST_Slope'] == 'Up') & (df['HeartDisease'] == 1)].count()
count_down_HR = df[(df['ST_Slope'] == 'Down') & (df['HeartDisease'] == 1)].count()
# Out:
# Flat    459
# Up      395
# Down     63
# Name: ST_Slope, dtype: int64
# Age               49
# Sex               49
# ChestPainType     49
# RestingBP         49
# Cholesterol       49
# FastingBS         49
# RestingECG        49
# MaxHR             49
# ExerciseAngina    49
# Oldpeak           49
# ST_Slope          49
# HeartDisease      49
# dtype: int64

# %%
In this data, there are 459 participants with a Flat st slope, 395 with up, and 63 with down.
Out of the 459 with Flat slope, 380 have heart disease.
Out of the 397 with Up slope, 78 have heart disease.
Out of the 63 with Down slope, 49 have heart disease.

# %%
# Defining the function for ecdf below
def ecdf(x):
    xs = np.sort(x)
    ys = np.arange(1, len(xs)+1)/float(len(xs))
    return xs, ys

# %%
# Creating the ECDF chart for the ST_Slope feature

np.random.seed(123)
values_flatslope = np.random.binomial(100,380/459,1000)
values_upslope = np.random.binomial(100, 78/395,1000)
values_downslope = np.random.binomial(100, 49/63,1000)

x_flat,y_flat = ecdf(values_flatslope)
x_up, y_up = ecdf(values_upslope)
x_down, y_down = ecdf(values_downslope)

plt.plot(x_flat,y_flat, color='blue', label='Flat', linestyle='none',marker='.')
plt.plot(x_up, y_up, color='red', label='Up', linestyle='none',marker='.')
plt.plot(x_down, y_down, color='green',label='Down', linestyle='none',marker='.')

plt.xlabel('Number of people with Heart Disease')
plt.ylabel('CDF')
plt.legend(loc='upper left')
plt.title('ECDF of ST Slope and People with Heart Disease')
plt.show()

# %%
I decided to create a ECDF chart for ST_Slope feature because the 'Flat' slope showed the biggest relation between
having and not having Heart Disease.

The chart above shows explains the following: 
Out of 100 samples of people with "Up" ST slope, 95% of the time ~25 people had Heart Disease
Out of 100 samples of people with "Flat" ST slope, 95% of the time ~90 people had Heart Disease
Out of 100 samples of people with "Down" ST slope, 95% of the time ~80 people had Heart Disease


The 'Flat' and 'Down' ST slopes are a very telling sign that a person will have heart disease.

# %% [markdown]
# # ECDF Analysis for 'ChestPain' Feature

# %%
# Count of people with each type of chest pain
count_ct = df['ChestPainType'].value_counts()
count_ct
# Out:
# ASY    496
# NAP    202
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
# Count of people with chest pain type that have Heart Disease

count_ta = df[(df['ChestPainType'] == 'TA') & (df['HeartDisease'] == 1)].count()
count_ata = df[(df['ChestPainType'] == 'ATA') & (df['HeartDisease'] == 1)].count()
count_nap = df[(df['ChestPainType'] == 'NAP') & (df['HeartDisease'] == 1)].count()
count_asy = df[(df['ChestPainType'] == 'ASY') & (df['HeartDisease'] == 1)].count()

# %%
values_ta = np.random.binomial(100,20/46,1000)
values_nap = np.random.binomial(100,71/202,1000)
values_ata = np.random.binomial(100,24/173,1000)
values_asy = np.random.binomial(100,392/496,1000)

x_ta, y_ta = ecdf(values_ta)
x_nap,y_nap = ecdf(values_nap)
x_ata, y_ata = ecdf(values_ata)
x_asy, y_asy = ecdf(values_asy)

plt.plot(x_ta,y_ta, color='blue', label='Typical Angina', linestyle='none',marker='.')
plt.plot(x_nap,y_nap, color='red', label='Non-Anginal Pain', linestyle='none',marker='.')
plt.plot(x_ata,y_ata, color='yellow', label='Atypical Angina', linestyle='none',marker='.')
plt.plot(x_asy,y_asy, color='green', label='Asymptotic', linestyle='none',marker='.')

plt.xlabel('Number of people with Heart Disease')
plt.ylabel('CDF')
plt.legend(loc='upper left')
plt.title('ECDF of Chest Pain Type vs Heart Disease')
plt.show()

# %%
Out of 100 samples of people with "Atypical Angina", 95% of the time ~20 people had Heart Disease
Out of 100 samples of people with 'Non-Anginal Pain', 95% of the time ~45 people had Heart Disease
Out of 100 samples of people with 'Atypical Angina', 95% of the time ~50 people had Heart Disease
Out of 100 samples of people for people that were 'Asymptotic', 95% of the time ~85 people had Heart Disease

This data shows that the 'Silent Heart Attack' aka 'Asymptotic' Heart Attack can be a clear sign of Heart Disease.

# %%
sns.heatmap(df.corr(),annot=True,linewidths=.05)
# Out:
# <AxesSubplot:>

# %%
The quantitative data doesn't show any strong correlations either positively or negatively.

# %%
I will use the Cramers_V to find correlations within the Categorical Variables
# Out:
#   Input In [256]
#     I will use the Cramers_V to find correlations within the Categorical Variables
#       ^
# SyntaxError: invalid syntax

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
cramers_v(df['ST_Slope'],df['HeartDisease'])
# Out:
# 0.6209180557213002

# %% [markdown]
# Since the Degrees of Freedom is 1 (min of 2 columns - 1), this is a statistically significant correlation

# %%
cramers_v(df['ChestPainType'],df['HeartDisease'])
# Out:
# 0.5387731692972357

# %%
With DOF of 1, 0.53 is a statistically significant association between these 2 variables

# %%
cramers_v(df['RestingECG'],df['HeartDisease'])
# Out:
# 0.09949306019187394

# %%
Similar to the RestingECG catplot, there is no correlation between RestingECG and HeartDisease

# %%
cramers_v(df['ExerciseAngina'],df['HeartDisease'])
# Out:
# 0.4924167071256221

# %%
Strong correlation between having Heart Disease and Exercise Angina, as expected based on the catplot from earlier

# %%
cramers_v(df['FastingBS'],df['HeartDisease'])
# Out:
# 0.2634800809276752

# %%
This correlation isn't as strong as expected based on the Catplot from earlier.

# %% [markdown]
# # Conclusion

# %%
The most important conclusion seen from the Exploratory Data Analysis is people with a 'Flat' or 'Down' ST slope
and people with 'Asymptotic' Chest Pain have the highest chance of having a Heart Disease.

We also noticed that people that experience Exercise Angina tend to have heart disease,
this is the same for people that have a Fasting Blood Sugar above 120 mg/dl.

Resting ECG doesn't tell us much about whether or not a person has heart disease.

Middle Aged Men are the most likely to have Heart Disease based on the data.
